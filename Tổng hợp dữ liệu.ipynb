# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/workspace/VPBank_Hackathon/src/Data'

# %%
crm_call_center_file = "CRM Call Center Logs.csv"
crm_events_file = "CRM Events.csv"
crm_review_file = "CRM Reviews.csv"
luxury_loan_portfolio_file = "LuxuryLoanPortfolio.csv"
completed_acct_file = "completedacct.csv"
completed_card_file = "completedcard.csv"
completed_client_file = "completedclient.csv"
completed_disposition_file = "completeddisposition.csv"
completed_loan_file = "completedloan.csv"
completed_district_file = "completeddistrict.csv"
completed_order_file = "completedorder.csv"
completed_trans_file = "completedtrans.csv"

# %%
crm_call_center_df = pd.read_csv(os.path.join(DATA_PATH, crm_call_center_file))
crm_events_df = pd.read_csv(os.path.join(DATA_PATH, crm_events_file))
crm_users_df = pd.read_csv(os.path.join(DATA_PATH, crm_review_file),  encoding='unicode_escape')
luxury_loan_portfolio_df = pd.read_csv(os.path.join(DATA_PATH, luxury_loan_portfolio_file))
completed_acct_df = pd.read_csv(os.path.join(DATA_PATH, completed_acct_file))
completed_card_df = pd.read_csv(os.path.join(DATA_PATH, completed_card_file))
completed_client_df = pd.read_csv(os.path.join(DATA_PATH, completed_client_file))
completed_disposition_df = pd.read_csv(os.path.join(DATA_PATH, completed_disposition_file))
completed_loan_df = pd.read_csv(os.path.join(DATA_PATH, completed_loan_file))
completed_district_df = pd.read_csv(os.path.join(DATA_PATH, completed_district_file))
completed_order_df = pd.read_csv(os.path.join(DATA_PATH, completed_order_file))
completed_trans_df = pd.read_csv(os.path.join(DATA_PATH, completed_trans_file))

# %%
max(completed_loan_df['fulldate'])
# Out:
# '2018-12-08'

# %%
completed_loan_df['account_id'].value_counts()
# Out:
# account_id
# A00003354    1
# A00004981    1
# A00003556    1
# A00003562    1
# A00009645    1
#             ..
# A00000002    1
# A00007401    1
# A00004533    1
# A00009208    1
# A00007542    1
# Name: count, Length: 682, dtype: int64

# %%
completed_order_df
# Out:
#       order_id account_id bank_to  account_to  amount           k_symbol
# 0        29401  A00000001      YZ    87144583  2452.0  Household Payment
# 1        29402  A00000002      ST    89597016  3372.7       Loan Payment
# 2        29403  A00000002      QR    13943797  7266.0  Household Payment
# 3        29404  A00000003      WX    83084338  1135.0  Household Payment
# 4        29405  A00000003      CD    24485939   327.0
# ...        ...        ...     ...         ...     ...                ...
# 6466     46334  A00011362      YZ    70641225  4780.0  Household Payment
# 6467     46335  A00011362      MN    78507822    56.0
# 6468     46336  A00011362      ST    40799850   330.0  Insurance Payment
# 6469     46337  A00011362      KL    20009470   129.0
# 6470     46338  A00011362      MN    61540514  5392.0       Loan Payment
#
# [6471 rows x 6 columns]

# %%
completed_trans_df['operation']
# Out:
# 0          Credit in Cash
# 1          Credit in Cash
# 2          Credit in Cash
# 3          Credit in Cash
# 4          Credit in Cash
#                 ...
# 1056315               NaN
# 1056316               NaN
# 1056317               NaN
# 1056318               NaN
# 1056319               NaN
# Name: operation, Length: 1056320, dtype: object

# %%
max(completed_card_df['fulldate'])
# Out:
# '2018-12-29'

# %%
luxury_loan_portfolio_df
# Out:
#         loan_id  funded_amount funded_date  duration years  duration months  \
# 0     LL0000076       790000.0  2012-04-27              20              240
# 1     LL0000151      1720000.0  2014-10-14              15              180
# 2     LL0000161      3720000.0  2014-06-07              15              180
# 3     LL0000175      1079000.0  2012-02-23              20              240
# 4     LL0000178      2028000.0  2016-04-01              20              240
# ...         ...            ...         ...             ...              ...
# 1673  LL0001228       528000.0  2012-11-10              20              240
# 1674  LL0001358       885000.0  2015-08-16              20              240
# 1675  LL0001479      1530000.0  2014-09-01              20              240
# 1676  LL0001561       897000.0  2014-02-14              15              180
# 1677  LL0001674      1656000.0  2016-07-12              15              180
#
# ...

# %%
luxury_loan_portfolio_df.columns
# Out:
# Index(['loan_id', 'funded_amount', 'funded_date', 'duration years',
#        'duration months', '10 yr treasury index date funded',
#        'interest rate percent', 'interest rate', 'payments',
#        'total past payments', 'loan balance', 'property value', 'purpose',
#        'firstname', 'middlename', 'lastname', 'social', 'phone', 'title',
#        'employment length', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS 1', 'ADDRESS 2', 'ZIP CODE',
#        'CITY', 'STATE', 'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
#        'TAX CLASS AT TIME OF SALE'],
#       dtype='object')

# %%
completed_acct_df
# Out:
#      account_id  district_id         frequency  parseddate  year  month  day
# 0     A00000576           55  Monthly Issuance  2013-01-01  2013      1    1
# 1     A00003818           74  Monthly Issuance  2013-01-01  2013      1    1
# 2     A00000704           55  Monthly Issuance  2013-01-01  2013      1    1
# 3     A00002378           16  Monthly Issuance  2013-01-01  2013      1    1
# 4     A00002632           24  Monthly Issuance  2013-01-02  2013      1    2
# ...         ...          ...               ...         ...   ...    ...  ...
# 4495  A00000124           55  Monthly Issuance  2017-12-28  2017     12   28
# 4496  A00003958           59  Monthly Issuance  2017-12-28  2017     12   28
# 4497  A00000777           30  Monthly Issuance  2017-12-28  2017     12   28
# 4498  A00001573           63  Monthly Issuance  2017-12-29  2017     12   29
# 4499  A00003276            1  Monthly Issuance  2017-12-29  2017     12   29
#
# [4500 rows x 7 columns]

# %%
group_account_trans_df = completed_trans_df.groupby(by=['account_id', 'k_symbol', 'type']).agg({'amount': 'sum', 'fulldate': 'count'})

# %%
group_account_trans_df =group_account_trans_df.reset_index()

# %%
group_account_trans_df['money_pre_month'] = group_account_trans_df['amount'] / group_account_trans_df['fulldate']

# %%
group_account_trans_df
# Out:
#       account_id              k_symbol    type    amount  fulldate  \
# 0      A00000001             Household   Debit   98080.0        40
# 1      A00000001     Interest Credited  Credit    3065.5        45
# 2      A00000001  Payment on Statement   Debit     584.0        40
# 3      A00000002             Household   Debit  472290.0        65
# 4      A00000002     Interest Credited  Credit   10717.5        70
# ...          ...                   ...     ...       ...       ...
# 15630  A00011362          Loan Payment   Debit  129408.0        24
# 15631  A00011362  Payment on Statement   Debit     481.8        33
# 15632  A00011382     Interest Credited  Credit   11026.5        80
# 15633  A00011382  Payment on Statement   Debit     511.0        35
# 15634  A00011382     Sanction Interest   Debit      20.4         8
#
#        money_pre_month
# 0          2452.000000
# 1            68.122222
# 2            14.600000
# 3          7266.000000
# 4           153.107143
# ...

# %%
group_account_trans_df['k_symbol'].value_counts()
# Out:
# k_symbol
# Interest Credited       4453
# Payment on Statement    4396
# Household               3297
#                         1293
# Old Age Pension          740
# Loan Payment             682
# Insurance Payment        510
# Sanction Interest        264
# Name: count, dtype: int64

# %%
# len(completed_trans_df[(completed_trans_df['account_id'] == 'A00000001') & (completed_trans_df['k_symbol'] == 'Payment on Statement')])

# %%
completed_order_df['k_symbol'].value_counts()
# Out:
# k_symbol
# Household Payment    3502
#                      1379
# Loan Payment          717
# Insurance Payment     532
# Leasing Payment       341
# Name: count, dtype: int64

# %%
completed_order_df
# Out:
#       order_id account_id bank_to  account_to  amount           k_symbol
# 0        29401  A00000001      YZ    87144583  2452.0  Household Payment
# 1        29402  A00000002      ST    89597016  3372.7       Loan Payment
# 2        29403  A00000002      QR    13943797  7266.0  Household Payment
# 3        29404  A00000003      WX    83084338  1135.0  Household Payment
# 4        29405  A00000003      CD    24485939   327.0
# ...        ...        ...     ...         ...     ...                ...
# 6466     46334  A00011362      YZ    70641225  4780.0  Household Payment
# 6467     46335  A00011362      MN    78507822    56.0
# 6468     46336  A00011362      ST    40799850   330.0  Insurance Payment
# 6469     46337  A00011362      KL    20009470   129.0
# 6470     46338  A00011362      MN    61540514  5392.0       Loan Payment
#
# [6471 rows x 6 columns]

# %%
completed_card_df['type'].value_counts()
# Out:
# type
# VISA Signature    659
# VISA Standard     145
# VISA Infinite      88
# Name: count, dtype: int64

# %%
order_map_trans = {
    'Household Payment': 'Household',
    'Loan Payment': 'Loan Payment',
    'Insurance Payment': 'Insurance Payment'
}

trans_map_order = {
    'Household': 'Household Payment',
    'Loan Payment': 'Loan Payment',
    'Insurance Payment': 'Insurance Payment'
}

# %%
account_order = completed_order_df['account_id'].unique().tolist()

# %%
accounts = []
count = 0
df_check = None
for idx, row in group_account_trans_df.iterrows():
    account_id = row['account_id']
    k_symbol_trans = row['k_symbol']
    amount_per_month = row['money_pre_month']
    if account_id in account_order:
      df_temp = completed_order_df[(completed_order_df['account_id'] == account_id) & (completed_order_df['amount'] == amount_per_month)]
      if df_check is None:
        df_check = df_temp
      else:
        df_check = pd.concat([df_check, df_temp])
      count += 1

# %%
cash_in_df = completed_trans_df[completed_trans_df['bank'].isna()].groupby(by=['account_id']).agg({'amount': 'sum', 'trans_id': 'count'}).reset_index()
cash_in_df.rename({'amount': 'amount_cash_in', 'trans_id': 'trans_cash_in_count'}, axis=1, inplace=True)
cash_out_df = completed_trans_df[~completed_trans_df['bank'].isna()].groupby(by=['account_id']).agg({'amount': 'sum', 'trans_id': 'count'}).reset_index()
cash_out_df.rename({'amount': 'amount_cash_out', 'trans_id': 'trans_cash_out_count'}, axis=1, inplace=True)

# %%
cash_in_df
# Out:
#      account_id  amount_cash_in  trans_cash_in_count
# 0     A00000001        111539.5                  154
# 1     A00000002       1060308.5                  319
# 2     A00000003        230008.8                   78
# 3     A00000004         63357.4                   93
# 4     A00000005         34206.4                   51
# ...         ...             ...                  ...
# 4495  A00011333       3295795.5                  368
# 4496  A00011349       1293458.2                  184
# 4497  A00011359       1175264.8                  223
# 4498  A00011362       1020572.5                  184
# 4499  A00011382       1281969.9                  213
#
# [4500 rows x 3 columns]

# %%
cash_out_df
# Out:
#      account_id  amount_cash_out  trans_cash_out_count
# 0     A00000001         263635.0                    85
# 1     A00000002        2091170.8                   159
# 2     A00000003          65013.0                    39
# 3     A00000004         287614.0                    93
# 4     A00000005         132675.0                    33
# ...         ...              ...                   ...
# 3707  A00011328          23370.0                     5
# 3708  A00011349        2663914.0                   120
# 3709  A00011359        1772816.6                   155
# 3710  A00011362         309438.0                   160
# 3711  A00011382        1341192.0                    40
#
# [3712 rows x 3 columns]

# %%
completed_order_df[~completed_order_df['order_id'].isin(df_check['order_id'].unique())]
# Out:
#       order_id account_id bank_to  account_to  amount           k_symbol
# 1        29402  A00000002      ST    89597016  3372.7       Loan Payment
# 14       29415  A00000010      QR    93182509  1344.0    Leasing Payment
# 15       29416  A00000011      ST    38470870  2132.0  Household Payment
# 38       29442  A00000030      EF    66168540  2480.2    Leasing Payment
# 41       29445  A00000034      WX    21845197  1479.0    Leasing Payment
# ...        ...        ...     ...         ...     ...                ...
# 6438     45974  A00011138      YZ    73215025  3744.7       Loan Payment
# 6439     45978  A00011141      QR    68096905  3744.7       Loan Payment
# 6460     46289  A00011333      IJ    99705963  3286.7    Leasing Payment
# 6467     46335  A00011362      MN    78507822    56.0
# 6469     46337  A00011362      KL    20009470   129.0
#
# [1002 rows x 6 columns]

# %%
completed_trans_df[(completed_trans_df['account_id'] == 'A00000002') & (completed_trans_df['amount'] == 3372.7)]
# Out:
#         column_a   trans_id account_id   type                   operation  \
# 31658      31659  T00000361  A00000002  Debit  Remittance to Another Bank
# 39503      39504  T00000362  A00000002  Debit  Remittance to Another Bank
# 45265      45266  T00000363  A00000002  Debit  Remittance to Another Bank
# 51676      51677  T00000364  A00000002  Debit  Remittance to Another Bank
# 58415      58416  T00000365  A00000002  Debit  Remittance to Another Bank
# 65909      65910  T00000366  A00000002  Debit  Remittance to Another Bank
# 73547      73548  T00000367  A00000002  Debit  Remittance to Another Bank
# 81026      81027  T00000368  A00000002  Debit  Remittance to Another Bank
# 88734      88735  T00000369  A00000002  Debit  Remittance to Another Bank
# 96668      96669  T00000370  A00000002  Debit  Remittance to Another Bank
# 104904    104905  T00000371  A00000002  Debit  Remittance to Another Bank
# 113793    113794  T00000372  A00000002  Debit  Remittance to Another Bank
# ...

# %%
completed_trans_df['operation'].value_counts()
# Out:
# operation
# Cash Withdrawal                 434918
# Remittance to Another Bank      208283
# Credit in Cash                  156743
# Collection from Another Bank     65226
# Credit Card Withdrawal            8036
# Name: count, dtype: int64

# %%
completed_trans_df[completed_trans_df['operation']=='Collection from Another Bank']
# Out:
#          column_a   trans_id account_id    type                     operation  \
# 15             16  T00637742  A00002177  Credit  Collection from Another Bank
# 17             18  T00232961  A00000793  Credit  Collection from Another Bank
# 21             22  T00542216  A00001844  Credit  Collection from Another Bank
# 24             25  T00579374  A00001972  Credit  Collection from Another Bank
# 46             47  T01049882  A00003592  Credit  Collection from Another Bank
# ...           ...        ...        ...     ...                           ...
# 1047119   1047120  T00551866  A00001879  Credit  Collection from Another Bank
# 1047121   1047122  T00549190  A00001871  Credit  Collection from Another Bank
# 1047122   1047123  T00546460  A00001860  Credit  Collection from Another Bank
# 1047127   1047128  T00605757  A00002062  Credit  Collection from Another Bank
# 1047137   1047138  T00519257  A00001773  Credit  Collection from Another Bank
#
# ...

# %%
last_trans_account = completed_trans_df.drop_duplicates(subset='account_id', keep='last')

# %%
first_trans_account = completed_trans_df.drop_duplicates(subset='account_id', keep='first')

# %%
trans_account_synthesis = pd.merge(first_trans_account, last_trans_account, on='account_id', how='inner', suffixes= ('_first', '_last'))

# %%
trans_account_synthesis['fulldate_last_pre'] = pd.to_datetime(trans_account_synthesis['fulldate_last'], format='%Y-%m-%d')
trans_account_synthesis['fulldate_first_pre'] = pd.to_datetime(trans_account_synthesis['fulldate_first'], format='%Y-%m-%d')
trans_account_synthesis['diff_date'] = (trans_account_synthesis['fulldate_last_pre'] - trans_account_synthesis['fulldate_first_pre']).dt.days

# %%
columns_used = ['account_id', 'balance_last', 'diff_date','date_last']
trans_last_synthesis_df = trans_account_synthesis[columns_used]

# %%
luxury_loan_portfolio_df.head(5)
# Out:
#      loan_id  funded_amount funded_date  duration years  duration months  \
# 0  LL0000076       790000.0  2012-04-27              20              240
# 1  LL0000151      1720000.0  2014-10-14              15              180
# 2  LL0000161      3720000.0  2014-06-07              15              180
# 3  LL0000175      1079000.0  2012-02-23              20              240
# 4  LL0000178      2028000.0  2016-04-01              20              240
#
#    10 yr treasury index date funded  interest rate percent  interest rate  \
# 0                              1.96                  3.359        0.03359
# 1                              2.21                  3.508        0.03508
# 2                              2.60                  3.896        0.03896
# 3                              1.99                  3.389        0.03389
# 4                              1.79                  3.188        0.03188
#
#    payments  total past payments  ...  BUILDING CLASS AT PRESENT  \
# ...

# %%
luxury_loan_portfolio_df['phone']
# Out:
# 0       542-843-5089
# 1       625-614-0118
# 2       255-592-5290
# 3       757-337-7073
# 4       478-573-2416
#             ...
# 1673    341-197-7229
# 1674    915-662-1564
# 1675    387-918-8796
# 1676    794-476-6508
# 1677    944-832-7169
# Name: phone, Length: 1678, dtype: object

# %%
luxury_loan_portfolio_df['firstname']
# Out:
# 0          Devin
# 1          Rhett
# 2            Jax
# 3       Nicholas
# 4          Riley
#           ...
# 1673        King
# 1674       Mason
# 1675       Tyson
# 1676      Ximena
# 1677    Jonathan
# Name: firstname, Length: 1678, dtype: object

# %%
luxury_loan_portfolio_df['lastname']
# Out:
# 0         Walters
# 1        Calderon
# 2        Richards
# 3          Priest
# 4         Hoffman
#           ...
# 1673     Saunders
# 1674      Robbins
# 1675    Maldonado
# 1676     Marshall
# 1677         Jean
# Name: lastname, Length: 1678, dtype: object

# %%
luxury_loan_portfolio_df.social
# Out:
# 0       972-69-4236
# 1       577-13-5838
# 2       263-55-1721
# 3       512-60-5121
# 4       271-64-4634
#            ...
# 1673    118-82-8393
# 1674    134-32-0424
# 1675    361-45-1730
# 1676    274-93-0056
# 1677    607-32-8064
# Name: social, Length: 1678, dtype: object

# %%
completed_client_df
# Out:
#       client_id     sex    fulldate  day  month  year  age       social  \
# 0     C00000001  Female  1990-12-13   13     12  1990   29  926-93-2157
# 1     C00000002    Male  1965-02-04    4      2  1965   54  806-94-5725
# 2     C00000003  Female  1960-10-09    9     10  1960   59  614-70-9100
# 3     C00000004    Male  1976-12-01    1     12  1976   43  580-20-3414
# 4     C00000005  Female  1980-07-03    3      7  1980   39  536-14-5809
# ...         ...     ...         ...  ...    ...   ...  ...          ...
# 5364  C00013955  Female  1965-10-30   30     10  1965   54  830-38-3530
# 5365  C00013956    Male  1963-04-06    6      4  1963   56  773-25-4409
# 5366  C00013968    Male  1988-04-13   13      4  1988   31  227-17-0778
# 5367  C00013971  Female  1982-10-19   19     10  1982   37  278-77-3298
# 5368  C00013998  Female  1973-08-12   12      8  1973   46  266-21-2541
#
#          first      middle      last         phone  \
# ...

# %%
df_merge_test = pd.merge(completed_client_df, luxury_loan_portfolio_df, on='social', how='inner')

# %%
luxury_loan_portfolio_df.columns
# Out:
# Index(['loan_id', 'funded_amount', 'funded_date', 'duration years',
#        'duration months', '10 yr treasury index date funded',
#        'interest rate percent', 'interest rate', 'payments',
#        'total past payments', 'loan balance', 'property value', 'purpose',
#        'firstname', 'middlename', 'lastname', 'social', 'phone', 'title',
#        'employment length', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS 1', 'ADDRESS 2', 'ZIP CODE',
#        'CITY', 'STATE', 'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
#        'TAX CLASS AT TIME OF SALE'],
#       dtype='object')

# %%
luxury_loan_portfolio_df.title
# Out:
# 0       Vice President Global Field Services
# 1                    Senior program manager
# 2                                        NaN
# 3                              Vice presiden
# 4                             Bank examiner
#                         ...
# 1673                         franchise owner
# 1674                 Chief Operating Officer
# 1675                         Owner/physician
# 1676                          General Manger
# 1677         Vice President, Capital Markets
# Name: title, Length: 1678, dtype: object

# %%
df_merge_loan = pd.merge(completed_loan_df, luxury_loan_portfolio_df, on='loan_id', how='inner')

# %%
df_merge_loan
# Out:
# Empty DataFrame
# Columns: [loan_id, account_id, amount, duration, payments_x, status, year, month, day, fulldate, location, purpose_x, funded_amount, funded_date, duration years, duration months, 10 yr treasury index date funded, interest rate percent, interest rate, payments_y, total past payments, loan balance, property value, purpose_y, firstname, middlename, lastname, social, phone, title, employment length, BUILDING CLASS CATEGORY, TAX CLASS AT PRESENT, BUILDING CLASS AT PRESENT, ADDRESS 1, ADDRESS 2, ZIP CODE, CITY, STATE, TOTAL UNITS, LAND SQUARE FEET, GROSS SQUARE FEET, TAX CLASS AT TIME OF SALE]
# Index: []
#
# [0 rows x 43 columns]

# %%
completed_loan_df[completed_loan_df['loan_id']=="L0000076"]
# Out:
# Empty DataFrame
# Columns: [loan_id, account_id, amount, duration, payments, status, year, month, day, fulldate, location, purpose]
# Index: []

# %%
completed_acct_df
# Out:
#      account_id  district_id         frequency  parseddate  year  month  day
# 0     A00000576           55  Monthly Issuance  2013-01-01  2013      1    1
# 1     A00003818           74  Monthly Issuance  2013-01-01  2013      1    1
# 2     A00000704           55  Monthly Issuance  2013-01-01  2013      1    1
# 3     A00002378           16  Monthly Issuance  2013-01-01  2013      1    1
# 4     A00002632           24  Monthly Issuance  2013-01-02  2013      1    2
# ...         ...          ...               ...         ...   ...    ...  ...
# 4495  A00000124           55  Monthly Issuance  2017-12-28  2017     12   28
# 4496  A00003958           59  Monthly Issuance  2017-12-28  2017     12   28
# 4497  A00000777           30  Monthly Issuance  2017-12-28  2017     12   28
# 4498  A00001573           63  Monthly Issuance  2017-12-29  2017     12   29
# 4499  A00003276            1  Monthly Issuance  2017-12-29  2017     12   29
#
# [4500 rows x 7 columns]

# %%
completed_disposition_df
# Out:
#         disp_id  client_id account_id   type
# 0     D00000001  C00000001  A00000001  Owner
# 1     D00000002  C00000002  A00000002  Owner
# 2     D00000003  C00000003  A00000002   User
# 3     D00000004  C00000004  A00000003  Owner
# 4     D00000005  C00000005  A00000003   User
# ...         ...        ...        ...    ...
# 5364  D00013647  C00013955  A00011349  Owner
# 5365  D00013648  C00013956  A00011349   User
# 5366  D00013660  C00013968  A00011359  Owner
# 5367  D00013663  C00013971  A00011362  Owner
# 5368  D00013690  C00013998  A00011382  Owner
#
# [5369 rows x 4 columns]

# %%
completed_trans_df
# Out:
#          column_a   trans_id account_id    type       operation  amount  \
# 0               1  T00695247  A00002378  Credit  Credit in Cash   700.0
# 1               2  T00171812  A00000576  Credit  Credit in Cash   900.0
# 2               3  T00207264  A00000704  Credit  Credit in Cash  1000.0
# 3               4  T01117247  A00003818  Credit  Credit in Cash   600.0
# 4               5  T00579373  A00001972  Credit  Credit in Cash   400.0
# ...           ...        ...        ...     ...             ...     ...
# 1056315   1056316  T03626622  A00002906  Credit             NaN    62.3
# 1056316   1056317  T03627616  A00002935  Credit             NaN    81.3
# 1056317   1056318  T03625403  A00002869  Credit             NaN    60.2
# 1056318   1056319  T03626683  A00002907  Credit             NaN   107.5
# 1056319   1056320  T03626540  A00002902  Credit             NaN   164.1
#
#          balance           k_symbol bank  account  year  month  day  \
# ...

# %%
credit_trans_df = completed_trans_df[(completed_trans_df['type'] == 'Credit') & (completed_trans_df['operation'] != 'Collection from Another Bank') \
                                     & (completed_trans_df['bank'].isna())].groupby(by=['account_id','type']).agg({'amount': 'sum', 'trans_id':'count'}).reset_index()
credit_trans_df.rename(columns={'trans_id': 'trans_count', 'amount': 'amount_credit'}, inplace=True)

# %%
credit_trans_df
# Out:
#      account_id    type  amount_credit  trans_count
# 0     A00000001  Credit        28765.5           57
# 1     A00000002  Credit        59117.5           82
# 2     A00000003  Credit       173059.0           46
# 3     A00000004  Credit         3544.0           31
# 4     A00000005  Credit         2162.0           16
# ...         ...     ...            ...          ...
# 4495  A00011333  Credit      1677057.6          183
# 4496  A00011349  Credit        22239.2           48
# 4497  A00011359  Credit        12364.2           53
# 4498  A00011362  Credit       684270.7           81
# 4499  A00011382  Credit        11226.5           81
#
# [4500 rows x 4 columns]

# %%
credit_trans_df['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
completed_loan_df.rename(columns={'amount': 'amount_loan', 'payment': 'payment_loan', 'status': 'status_loan', 'purpose': 'purpose_loan'}, inplace=True)

# %%
final_df = pd.merge(credit_trans_df, completed_loan_df, on='account_id', how='outer')
final_df = pd.merge(final_df, trans_last_synthesis_df[['account_id', 'balance_last','diff_date']], on='account_id', how='inner')

# %%
final_df.to_csv('/content/drive/MyDrive/workspace/VPBank_Hackathon/src/data_preprocessing/data_clv.csv', index=False)

# %% [markdown]
# ## Tổng hợp dữ liệu

# %%
completed_acct_df.head(5)
# Out:
#   account_id  district_id         frequency  parseddate  year  month  day
# 0  A00000576           55  Monthly Issuance  2013-01-01  2013      1    1
# 1  A00003818           74  Monthly Issuance  2013-01-01  2013      1    1
# 2  A00000704           55  Monthly Issuance  2013-01-01  2013      1    1
# 3  A00002378           16  Monthly Issuance  2013-01-01  2013      1    1
# 4  A00002632           24  Monthly Issuance  2013-01-02  2013      1    2

# %%
completed_disposition_df.head(5)
# Out:
#      disp_id  client_id account_id   type
# 0  D00000001  C00000001  A00000001  Owner
# 1  D00000002  C00000002  A00000002  Owner
# 2  D00000003  C00000003  A00000002   User
# 3  D00000004  C00000004  A00000003  Owner
# 4  D00000005  C00000005  A00000003   User

# %%
columns_cluster_used = ['client_id', 'age', 'state', 'city', 'district_id', 'sex']
client_df_used = completed_client_df[columns_cluster_used]
dispostion_client_df = pd.merge(completed_disposition_df, client_df_used, on='client_id', how='outer', suffixes=('_disposition', '_client'))

# %%
dispostion_client_df
# Out:
#         disp_id  client_id account_id   type  age state           city  \
# 0     D00000001  C00000001  A00000001  Owner   29    NM    Albuquerque
# 1     D00000002  C00000002  A00000002  Owner   54    NY  New York City
# 2     D00000003  C00000003  A00000002   User   59    NY  New York City
# 3     D00000004  C00000004  A00000003  Owner   43    IN   Indianapolis
# 4     D00000005  C00000005  A00000003   User   39    IN   Indianapolis
# ...         ...        ...        ...    ...  ...   ...            ...
# 5364  D00013647  C00013955  A00011349  Owner   54    NY  New York City
# 5365  D00013648  C00013956  A00011349   User   56    NY  New York City
# 5366  D00013660  C00013968  A00011359  Owner   31    MA     Fall River
# 5367  D00013663  C00013971  A00011362  Owner   37    CT        Danbury
# 5368  D00013690  C00013998  A00011382  Owner   46    IL        Chicago
#
#       district_id     sex
# 0              18  Female
# 1               1    Male
# 2               1  Female
# ...

# %%
card_dispostion_client_df = pd.merge(dispostion_client_df, completed_card_df, on='disp_id', how='outer', suffixes=('', '_card'))

# %%
card_dispostion_client_df
# Out:
#         disp_id  client_id account_id   type  age state           city  \
# 0     D00000001  C00000001  A00000001  Owner   29    NM    Albuquerque
# 1     D00000002  C00000002  A00000002  Owner   54    NY  New York City
# 2     D00000003  C00000003  A00000002   User   59    NY  New York City
# 3     D00000004  C00000004  A00000003  Owner   43    IN   Indianapolis
# 4     D00000005  C00000005  A00000003   User   39    IN   Indianapolis
# ...         ...        ...        ...    ...  ...   ...            ...
# 5364  D00013647  C00013955  A00011349  Owner   54    NY  New York City
# 5365  D00013648  C00013956  A00011349   User   56    NY  New York City
# 5366  D00013660  C00013968  A00011359  Owner   31    MA     Fall River
# 5367  D00013663  C00013971  A00011362  Owner   37    CT        Danbury
# 5368  D00013690  C00013998  A00011382  Owner   46    IL        Chicago
#
#       district_id     sex    card_id       type_card    year  month   day  \
# ...

# %%
final_df
# Out:
#      account_id    type  amount_credit  trans_count    loan_id  amount_loan  \
# 0     A00000001  Credit        28765.5           57        NaN          NaN
# 1     A00000002  Credit        59117.5           82  L00004959      80952.0
# 2     A00000003  Credit       173059.0           46        NaN          NaN
# 3     A00000004  Credit         3544.0           31        NaN          NaN
# 4     A00000005  Credit         2162.0           16        NaN          NaN
# ...         ...     ...            ...          ...        ...          ...
# 4495  A00011333  Credit      1677057.6          183        NaN          NaN
# 4496  A00011349  Credit        22239.2           48  L00007304     419880.0
# 4497  A00011359  Credit        12364.2           53  L00007305      54024.0
# 4498  A00011362  Credit       684270.7           81  L00007308     129408.0
# 4499  A00011382  Credit        11226.5           81        NaN          NaN
#
# ...

# %%
account_client_merge = pd.merge(card_dispostion_client_df, final_df, on='account_id', how='inner', suffixes=('', '_trans'))
data = pd.merge(cash_in_df, account_client_merge, on='account_id', how='outer')
data = pd.merge(cash_out_df, data, on='account_id', how='outer')

# %%
account_client_merge
# Out:
#         disp_id  client_id account_id   type  age state           city  \
# 0     D00000001  C00000001  A00000001  Owner   29    NM    Albuquerque
# 1     D00000002  C00000002  A00000002  Owner   54    NY  New York City
# 2     D00000003  C00000003  A00000002   User   59    NY  New York City
# 3     D00000004  C00000004  A00000003  Owner   43    IN   Indianapolis
# 4     D00000005  C00000005  A00000003   User   39    IN   Indianapolis
# ...         ...        ...        ...    ...  ...   ...            ...
# 5364  D00013647  C00013955  A00011349  Owner   54    NY  New York City
# 5365  D00013648  C00013956  A00011349   User   56    NY  New York City
# 5366  D00013660  C00013968  A00011359  Owner   31    MA     Fall River
# 5367  D00013663  C00013971  A00011362  Owner   37    CT        Danbury
# 5368  D00013690  C00013998  A00011382  Owner   46    IL        Chicago
#
#       district_id     sex    card_id  ... payments  status_loan  year_trans  \
# ...

# %%
data['is_has_loan'] = data['loan_id'].apply(lambda x: 1 if not pd.isna(x) else 0)
data['is_has_card'] = data['card_id'].apply(lambda x: 1 if not pd.isna(x) else 0)

# %%
data.columns
# Out:
# Index(['account_id', 'amount_cash_out', 'trans_cash_out_count',
#        'amount_cash_in', 'trans_cash_in_count', 'disp_id', 'client_id', 'type',
#        'age', 'state', 'city', 'district_id', 'sex', 'card_id', 'type_card',
#        'year', 'month', 'day', 'fulldate', 'type_trans', 'amount_credit',
#        'trans_count', 'loan_id', 'amount_loan', 'duration', 'payments',
#        'status_loan', 'year_trans', 'month_trans', 'day_trans',
#        'fulldate_trans', 'location', 'purpose_loan', 'balance_last',
#        'diff_date', 'is_has_loan', 'is_has_card'],
#       dtype='object')

# %%
data.head()
# Out:
#   account_id  amount_cash_out  trans_cash_out_count  amount_cash_in  \
# 0  A00000001         263635.0                  85.0        111539.5
# 1  A00000002        2091170.8                 159.0       1060308.5
# 2  A00000002        2091170.8                 159.0       1060308.5
# 3  A00000003          65013.0                  39.0        230008.8
# 4  A00000003          65013.0                  39.0        230008.8
#
#    trans_cash_in_count    disp_id  client_id   type  age state  ...  \
# 0                  154  D00000001  C00000001  Owner   29    NM  ...
# 1                  319  D00000002  C00000002  Owner   54    NY  ...
# 2                  319  D00000003  C00000003   User   59    NY  ...
# 3                   78  D00000004  C00000004  Owner   43    IN  ...
# 4                   78  D00000005  C00000005   User   39    IN  ...
#
#   year_trans  month_trans day_trans fulldate_trans location  purpose_loan  \
# ...

# %%
columns_cluster_final_used = ['client_id', 'account_id', 'age', 'state', 'city', 'district_id', 'sex', 'balance_last', 'diff_date', 'trans_count', 'amount_loan','amount_credit', 'is_has_loan', 'is_has_card']

# %%
data.to_csv('/content/drive/MyDrive/workspace/VPBank_Hackathon/src/data_preprocessing/data_train_ver2.csv', index=False)
